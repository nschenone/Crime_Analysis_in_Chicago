# %% [markdown]
# # Crime Analysis in Chicago (2001 vs. 2018)

# %% [markdown]
# ## Descriptive Data Analysis

# %% [markdown]
# ### Setup

# %%
# Imports
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500)
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (30, 15) #increase figure size

# %%
"""
# Read in datasets
df_2001_2004 = pd.read_csv("data/Chicago_Crimes_2001_to_2004.csv", error_bad_lines=False)
df_2005_2007 = pd.read_csv("data/Chicago_Crimes_2005_to_2007.csv", error_bad_lines=False)
df_2008_2011 = pd.read_csv("data/Chicago_Crimes_2008_to_2011.csv", error_bad_lines=False)
df_2012_2017 = pd.read_csv("data/Chicago_Crimes_2012_to_2017.csv", error_bad_lines=False)

# Create dataframes per year
df_2001 = df_2001_2004[df_2001_2004['Year'] == 2001]
df_2002 = df_2001_2004[df_2001_2004['Year'] == 2002]
df_2003 = df_2001_2004[df_2001_2004['Year'] == 2003]
df_2004 = df_2001_2004[df_2001_2004['Year'] == 2004]

df_2005 = df_2005_2007[df_2005_2007['Year'] == 2005]
df_2006 = df_2005_2007[df_2005_2007['Year'] == 2006]
df_2007 = df_2005_2007[df_2005_2007['Year'] == 2007]

df_2008 = df_2008_2011[df_2008_2011['Year'] == 2008]
df_2009 = df_2008_2011[df_2008_2011['Year'] == 2009]
df_2010 = df_2008_2011[df_2008_2011['Year'] == 2010]
df_2011 = df_2008_2011[df_2008_2011['Year'] == 2011]

df_2012 = df_2012_2017[df_2012_2017['Year'] == 2012]
df_2013 = df_2012_2017[df_2012_2017['Year'] == 2013]
df_2014 = df_2012_2017[df_2012_2017['Year'] == 2014]
df_2015 = df_2012_2017[df_2012_2017['Year'] == 2015]
df_2016 = df_2012_2017[df_2012_2017['Year'] == 2016]
df_2017 = df_2012_2017[df_2012_2017['Year'] == 2017]

# List with all datasets
export_datasets = [df_2001, df_2002, df_2003, df_2004, df_2005, df_2006, df_2007, df_2008, df_2009, df_2010, df_2011, df_2012, df_2013, df_2014, df_2015, df_2016, df_2017]

# Export dataframes into csv files per year
year = 2001
for dataset in export_datasets:
    name = "data/crime_" + str(year) + ".csv"
    cols = dataset.columns
    #df = pd.read_csv(name, )
    dataset.to_csv(name, index=False)
    #dataset.to_csv(name, index=False)
    year += 1

# Loop through csv files and resave to fix index column
year = 2001
for dataset in export_datasets:
    name = "crime_" + str(year) + ".csv"
    df = pd.read_csv("data/" + name).drop(dataset.columns[0], axis=1)
    df.to_csv("data/" + name, index=0)
    year += 1
""";

# %%
"""
# Load datasets from beginning, middle, and end years
df_2003 = pd.read_csv("data/crime_2003.csv")
df_2003.name = "Crime in 2003"

df_2007 = pd.read_csv("data/crime_2007.csv")
df_2007.name = "Crime in 2007"

df_2016 = pd.read_csv("data/crime_2016.csv")
df_2016.name = "Crime in 2016"

datasets = [df_2003, df_2007, df_2016]
"""

# Load all datasets
df_2001 = pd.read_csv("data/crime_2001.csv")
df_2001.name = "Crime in 2001"
df_2001.year = "2001"

df_2002 = pd.read_csv("data/crime_2002.csv")
df_2002.name = "Crime in 2002"
df_2002.year = "2002"

df_2003 = pd.read_csv("data/crime_2003.csv")
df_2003.name = "Crime in 2003"
df_2003.year = "2003"

df_2004 = pd.read_csv("data/crime_2004.csv")
df_2004.name = "Crime in 2004"
df_2004.year = "2004"

df_2005 = pd.read_csv("data/crime_2005.csv")
df_2005.name = "Crime in 2005"
df_2005.year = "2005"

df_2006 = pd.read_csv("data/crime_2006.csv")
df_2006.name = "Crime in 2006"
df_2006.year = "2006"

df_2007 = pd.read_csv("data/crime_2007.csv")
df_2007.name = "Crime in 2007"
df_2007.year = "2007"

df_2008 = pd.read_csv("data/crime_2008.csv")
df_2008.name = "Crime in 2008"
df_2008.year = "2008"

df_2009 = pd.read_csv("data/crime_2009.csv")
df_2009.name = "Crime in 2009"
df_2009.year = "2009"

df_2010 = pd.read_csv("data/crime_2010.csv")
df_2010.name = "Crime in 2010"
df_2010.year = "2010"

df_2011 = pd.read_csv("data/crime_2011.csv")
df_2011.name = "Crime in 2011"
df_2011.year = "2011"

df_2012 = pd.read_csv("data/crime_2012.csv")
df_2012.name = "Crime in 2012"
df_2012.year = "2012"

df_2013 = pd.read_csv("data/crime_2013.csv")
df_2013.name = "Crime in 2013"
df_2013.year = "2013"

df_2014 = pd.read_csv("data/crime_2014.csv")
df_2014.name = "Crime in 2014"
df_2014.year = "2014"

df_2015 = pd.read_csv("data/crime_2015.csv")
df_2015.name = "Crime in 2015"
df_2015.year = "2015"

df_2016 = pd.read_csv("data/crime_2016.csv")
df_2016.name = "Crime in 2016"
df_2016.year = "2016"

datasets = [df_2003,
            df_2004,
            df_2005,
            df_2006,
            df_2007,
            df_2008,
            df_2009,
            df_2010,
            df_2011,
            df_2012,
            df_2013,
            df_2014,
            df_2015,
            df_2016]
# Out:
# /Users/prettybeach/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Size

# %%
for dataset in datasets:
    print("Dataset: {}, Shape: {}".format(dataset.name, dataset.shape))
    print("test")
# Out:
# Dataset: Crime in 2003, Shape: (475913, 22)
# test
# Dataset: Crime in 2004, Shape: (388205, 22)
# test
# Dataset: Crime in 2005, Shape: (455811, 22)
# test
# Dataset: Crime in 2006, Shape: (794684, 22)
# test
# Dataset: Crime in 2007, Shape: (621848, 22)
# test
# Dataset: Crime in 2008, Shape: (852053, 22)
# test
# Dataset: Crime in 2009, Shape: (783900, 22)
# test
# Dataset: Crime in 2010, Shape: (700691, 22)
# test
# Dataset: Crime in 2011, Shape: (352066, 22)
# test
# Dataset: Crime in 2012, Shape: (335670, 22)
# test
# Dataset: Crime in 2013, Shape: (306703, 22)
# test
# Dataset: Crime in 2014, Shape: (274527, 22)
# test
# Dataset: Crime in 2015, Shape: (262995, 22)
# test
# Dataset: Crime in 2016, Shape: (265462, 22)
# test

# %% [markdown]
# ### Missingness

# %%
for dataset in datasets:
    print("Dataset: {}".format(dataset.name))
    print(dataset.isnull().sum())
    print('\n')
# Out:
# Dataset: Crime in 2003
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       2
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                      19
# Community Area            50
# FBI Code                   0
# X Coordinate            4728
# Y Coordinate            4728
# Year                       0
# Updated On                 0
# Latitude                4728
# Longitude               4728
# Location                4728
# dtype: int64
#
#
# Dataset: Crime in 2004
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       8
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   2
# Ward                      22
# Community Area            57
# FBI Code                   0
# X Coordinate            3304
# Y Coordinate            3304
# Year                       0
# Updated On                 0
# Latitude                3304
# Longitude               3304
# Location                3304
# dtype: int64
#
#
# Dataset: Crime in 2005
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       6
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   1
# Ward                       1
# Community Area            54
# FBI Code                   0
# X Coordinate            5189
# Y Coordinate            5189
# Year                       0
# Updated On                 0
# Latitude                5189
# Longitude               5189
# Location                5189
# dtype: int64
#
#
# Dataset: Crime in 2006
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description      14
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   2
# Ward                       6
# Community Area            80
# FBI Code                   0
# X Coordinate            2641
# Y Coordinate            2641
# Year                       0
# Updated On                 0
# Latitude                2641
# Longitude               2641
# Location                2641
# dtype: int64
#
#
# Dataset: Crime in 2007
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       5
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   2
# Ward                       8
# Community Area           215
# FBI Code                   0
# X Coordinate            1324
# Y Coordinate            1324
# Year                       0
# Updated On                 0
# Latitude                1324
# Longitude               1324
# Location                1324
# dtype: int64
#
#
# Dataset: Crime in 2008
# ID                          0
# Case Number                 0
# Date                        0
# Block                       0
# IUCR                        0
# Primary Type                0
# Description                 0
# Location Description        9
# Arrest                      0
# Domestic                    0
# Beat                        0
# District                   80
# Ward                        8
# Community Area            480
# FBI Code                    0
# X Coordinate            12528
# Y Coordinate            12528
# Year                        0
# Updated On                  0
# Latitude                12528
# Longitude               12528
# Location                12528
# dtype: int64
#
#
# Dataset: Crime in 2009
# ID                          0
# Case Number                 4
# Date                        0
# Block                       0
# IUCR                        0
# Primary Type                0
# Description                 0
# Location Description       12
# Arrest                      0
# Domestic                    0
# Beat                        0
# District                    0
# Ward                        6
# Community Area            438
# FBI Code                    0
# X Coordinate            12313
# Y Coordinate            12313
# Year                        0
# Updated On                  0
# Latitude                12313
# Longitude               12313
# Location                12313
# dtype: int64
#
#
# Dataset: Crime in 2010
# ID                         0
# Case Number                2
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description      15
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   2
# Ward                      35
# Community Area           349
# FBI Code                   0
# X Coordinate            2821
# Y Coordinate            2821
# Year                       0
# Updated On                 0
# Latitude                2821
# Longitude               2821
# Location                2821
# dtype: int64
#
#
# Dataset: Crime in 2011
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description    255
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  1
# Ward                     14
# Community Area          188
# FBI Code                  0
# X Coordinate            983
# Y Coordinate            983
# Year                      0
# Updated On                0
# Latitude                983
# Longitude               983
# Location                983
# dtype: int64
#
#
# Dataset: Crime in 2012
# ID                        0
# Case Number               1
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description    342
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                      7
# Community Area           26
# FBI Code                  0
# X Coordinate            917
# Y Coordinate            917
# Year                      0
# Updated On                0
# Latitude                917
# Longitude               917
# Location                917
# dtype: int64
#
#
# Dataset: Crime in 2013
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description      66
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   1
# Ward                       3
# Community Area            13
# FBI Code                   0
# X Coordinate            2388
# Y Coordinate            2388
# Year                       0
# Updated On                 0
# Latitude                2388
# Longitude               2388
# Location                2388
# dtype: int64
#
#
# Dataset: Crime in 2014
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     182
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       2
# Community Area             1
# FBI Code                   0
# X Coordinate            5062
# Y Coordinate            5062
# Year                       0
# Updated On                 0
# Latitude                5062
# Longitude               5062
# Location                5062
# dtype: int64
#
#
# Dataset: Crime in 2015
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description     257
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       2
# Community Area             0
# FBI Code                   0
# X Coordinate            3200
# Y Coordinate            3200
# Year                       0
# Updated On                 0
# Latitude                3200
# Longitude               3200
# Location                3200
# dtype: int64
#
#
# Dataset: Crime in 2016
# ID                          0
# Case Number                 0
# Date                        0
# Block                       0
# IUCR                        0
# Primary Type                0
# Description                 0
# Location Description      783
# Arrest                      0
# Domestic                    0
# Beat                        0
# District                    0
# Ward                        0
# Community Area              0
# FBI Code                    0
# X Coordinate            14189
# Y Coordinate            14189
# Year                        0
# Updated On                  0
# Latitude                14189
# Longitude               14189
# Location                14189
# dtype: int64

# %% [markdown]
# ### Remove rows with missing values

# %%
for dataset in datasets:
    dataset.dropna(inplace=True)

# %% [markdown]
# ### Number of crimes per year

# %%
years = []
data_len = []
for dataset in datasets:
    years.append(dataset.year)
    data_len.append(len(dataset))

df_num = pd.DataFrame({'Year': years,'Num Crimes': data_len}).set_index('Year')
df_num.plot(kind='bar', rot=0);

# %%
print("this is a test - github pls work")
# Out:
# this is a test - github pls work

# %% [markdown]
# ### Crime per community area (2003, 2007, 2016)

# %%
df_areas = pd.DataFrame()
df_areas['2003'] = df_2003['Community Area'].value_counts()
df_areas['2007'] = df_2007['Community Area'].value_counts()
df_areas['2016'] = df_2016['Community Area'].value_counts()
df_areas.plot(kind='bar', rot=90);

# %% [markdown]
# ## Latitude & Longtitude

# %%
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
crs={'init':'epsg:4326'}

# zip the Longtitude and Latitude together. Each point represents a row in Data frame
Geo_2003= [Point(xy) for xy in zip (df_2003["X Coordinate"],df_2003["Y Coordinate"])]
Geo_2007= [Point(xy) for xy in zip (df_2007["X Coordinate"],df_2007["Y Coordinate"])]
Geo_2016= [Point(xy) for xy in zip (df_2016["X Coordinate"],df_2016["Y Coordinate"])]

Geo_df_2003= gpd.GeoDataFrame(df_2003,crs=crs,geometry=Geo_2003)
Geo_df_2007= gpd.GeoDataFrame(df_2007,crs=crs,geometry=Geo_2007)
Geo_df_2016= gpd.GeoDataFrame(df_2016,crs=crs,geometry=Geo_2016)

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2003.plot(ax=ax,markersize=0.25)
ax.set_title('Crimes happened in Chicago in 2003')
# Out:
# Text(0.5, 1.0, 'Crimes happened in Chicago in 2003')

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2007.plot(ax=ax,markersize=0.25)
ax.set_title('Crimes happened in Chicago in 2007')
plt.show()

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2016.plot(ax=ax,markersize=0.25)
ax.set_title('Crimes happened in Chicago in 2016')
plt.show()

# %%
## You can change Primary Type to see different types.

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2003[Geo_df_2003['Primary Type']=='THEFT'].plot(ax=ax,markersize=0.25)
ax.set_title('Homicide happened in Chicago in 2003')
# Out:
# Text(0.5, 1.0, 'Homicide happened in Chicago in 2003')

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2007[Geo_df_2007['Primary Type']=='THEFT'].plot(ax=ax,markersize=0.25)
ax.set_title('Homicide happened in Chicago in 2007')
# Out:
# Text(0.5, 1.0, 'Homicide happened in Chicago in 2007')

# %%
fig,ax= plt.subplots(figsize=(8,8))
Geo_df_2016[Geo_df_2016['Primary Type']=='THEFT'].plot(ax=ax,markersize=0.25)
ax.set_title('Homicide happened in Chicago in 2016')
# Out:
# Text(0.5, 1.0, 'Homicide happened in Chicago in 2016')

# %% [markdown]
# ## Choropleth

# %%
fd='data/PoliceDistrict copy.shp'
map_Chicago=gpd.read_file(fd)
map_Chicago.drop(columns=['DIST_LABEL'],inplace=True)
map_Chicago["DIST_NUM"]=map_Chicago["DIST_NUM"].apply(pd.to_numeric)

district_2003=pd.DataFrame(df_2003['District'].value_counts())
district_2007=pd.DataFrame(df_2007['District'].value_counts())
district_2016=pd.DataFrame(df_2016['District'].value_counts())


district_2003=district_2003.reset_index().rename(columns={'index':'DIST_NUM','District':'CRIME_NUM'})
district_2007=district_2007.reset_index().rename(columns={'index':'DIST_NUM','District':'CRIME_NUM'})
district_2016=district_2016.reset_index().rename(columns={'index':'DIST_NUM','District':'CRIME_NUM'})

map_2003=map_Chicago.merge(district_2003,on='DIST_NUM')
map_2007=map_Chicago.merge(district_2007,on='DIST_NUM')
map_2016=map_Chicago.merge(district_2016,on='DIST_NUM')

# %%
SMALL_SIZE = 15
MEDIUM_SIZE = 18
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

plt.rcParams['figure.figsize'] = (25, 10) #increase figure size

# %%
fig, axs = plt.subplots(1,3)

sm = plt.cm.ScalarMappable(cmap='Greens')
sm._A = []
cbar = fig.colorbar(sm)
ax.axis('off')
ax.set_title('Crime happened in Chicago in 2003')


map_2003.plot(column="DIST_NUM", cmap='Greens', linewidth=0.8, ax=axs[0], edgecolor='0.6')
map_2007.plot(column="DIST_NUM", cmap='Greens', linewidth=0.8, ax=axs[1], edgecolor='0.6')
map_2016.plot(column="DIST_NUM", cmap='Greens', linewidth=0.8, ax=axs[2], edgecolor='0.6')

# %% [markdown]
# ## Get Data

# %%
Community=pd.DataFrame(pd.read_csv('Per_Capita_Income.csv'))
Community=Community.rename(columns={'PER CAPITA INCOME ':'Income'})
Community.head(5)
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  Income  HARDSHIP INDEX
# 0                              27.5   23939            39.0
# 1                              38.5   23040            46.0
# 2                              22.2   35787            20.0
# 3                              25.5   37524            17.0
# 4                              26.2   57123             6.0

# %% [markdown]
# ## Data Wrangling

# %%
Community['Income'].isnull().values.any()
# Out:
# False

# %%
set(list(Community))
# Out:
# {'COMMUNITY AREA NAME',
#  'Community Area Number',
#  'HARDSHIP INDEX',
#  'Income',
#  'PERCENT AGED 16+ UNEMPLOYED',
#  'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#  'PERCENT AGED UNDER 18 OR OVER 64',
#  'PERCENT HOUSEHOLDS BELOW POVERTY',
#  'PERCENT OF HOUSING CROWDED'}

# %%
Community.drop(columns=['PERCENT OF HOUSING CROWDED',
                'PERCENT HOUSEHOLDS BELOW POVERTY',
                'PERCENT AGED 16+ UNEMPLOYED',
                'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
                'PERCENT AGED UNDER 18 OR OVER 64',
                'PERCENT OF HOUSING CROWDED'],inplace=True)
Community.head(5)
# Out:
#    Community Area Number COMMUNITY AREA NAME  Income  HARDSHIP INDEX
# 0                    1.0         Rogers Park   23939            39.0
# 1                    2.0          West Ridge   23040            46.0
# 2                    3.0              Uptown   35787            20.0
# 3                    4.0      Lincoln Square   37524            17.0
# 4                    5.0        North Center   57123             6.0

# %% [markdown]
# ## Descriptive

# %%
Community.shape
# Out:
# (78, 9)

# %%
Community.describe()
# Out:
#        Community Area Number  PERCENT OF HOUSING CROWDED  \
# count              77.000000                   78.000000
# mean               39.000000                    4.920513
# std                22.371857                    3.658981
# min                 1.000000                    0.300000
# 25%                20.000000                    2.325000
# 50%                39.000000                    3.850000
# 75%                58.000000                    6.800000
# max                77.000000                   15.800000
#
#        PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# count                         78.000000                    78.000000
# mean                          21.739744                    15.341026
# std                           11.457231                     7.499497
# min                            3.300000                     4.700000
# 25%                           13.350000                     9.200000
# 50%                           19.050000                    13.850000
# 75%                           29.150000                    20.000000
# max                           56.500000                    35.900000
#
#        PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# count                                     78.000000
# mean                                      20.330769
# std                                       11.746514
# min                                        2.500000
# 25%                                       12.075000
# 50%                                       18.650000
# 75%                                       26.600000
# max                                       54.800000
#
#        PERCENT AGED UNDER 18 OR OVER 64        Income  HARDSHIP INDEX
# count                         78.000000     78.000000       77.000000
# mean                          35.717949  25597.000000       49.506494
# std                            7.284421  15196.405541       28.690556
# min                           13.500000   8201.000000        1.000000
# 25%                           32.150000  15804.750000       25.000000
# 50%                           38.050000  21668.500000       50.000000
# 75%                           40.500000  28715.750000       74.000000
# max                           51.500000  88669.000000       98.000000

# %%
plt.hist(Community['Income'],bins=10)
# Out:
# (array([23., 24., 13.,  8.,  4.,  0.,  3.,  2.,  0.,  1.]),
#  array([ 8201. , 16247.8, 24294.6, 32341.4, 40388.2, 48435. , 56481.8,
#         64528.6, 72575.4, 80622.2, 88669. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# The distribution of the per capita income is （ ）

# %% [markdown]
# Therefore, we apply log transformation on it.

# %%
Income10= pd.DataFrame({'Income10':np.log(Community["Income"])})
Community=Community.join('Income10')
plt.hist(Community['Income10'],bins=10)
# Out:
# (array([ 2., 10., 14., 12., 16.,  8.,  8.,  2.,  4.,  2.]),
#  array([ 9.01201138,  9.2500768 ,  9.48814222,  9.72620765,  9.96427307,
#         10.2023385 , 10.44040392, 10.67846934, 10.91653477, 11.15460019,
#         11.39266561]),
#  <a list of 10 Patch objects>)
